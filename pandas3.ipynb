# %%
import pandas as pd

df = pd.read_csv("Desktop/datasets/MinimumWageData.csv", encoding="latin")

# %%
df.to_csv("Desktop/datasets/MinimumWageData.csv", encoding = "utf-8")

df = pd.read_csv("Desktop/datasets/MinimumWageData.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# ...

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Low.value":name})
    else:
         act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Low.value":name}))

act_min_wage.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hn/prhq6hk57b7b0hljs67v7l9r0000gn/T/ipykernel_3514/3256980913.py in <module>
#       5         act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Low.value":name})
#       6     else:
# ----> 7          act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value"]].rename(columns={"Low.value":name}))
#       8
#       9 act_min_wage.head()
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# ...
