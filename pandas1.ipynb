# %%
import pandas as pd

df = pd.read_csv("Desktop/datasets/AllCountries.csv")

# %%
df
# Out:
#             Country  LandArea  Population  Density     GDP  Rural   CO2  \
# 0       Afghanistan    652.86      30.552     46.8   665.0   74.1  35.3
# 1           Albania     27.40       2.897    105.7  4460.0   44.6  12.8
# 2           Algeria   2381.74      39.208     16.5  5361.0   30.5  24.6
# 3    American Samoa      0.20       0.055    275.0     NaN   12.7   NaN
# 4           Andorra      0.47       0.079    168.1     NaN   13.8   9.5
# ..              ...       ...         ...      ...     ...    ...   ...
# 212     Yemen, Rep.    527.97      24.407     46.2  1473.0   66.6  31.5
# 213          Zambia    743.39      14.539     19.6  1845.0   60.0  43.0
# 214        Zimbabwe    386.85      14.150     36.6   953.0   67.3  31.6
# 215             NaN       NaN         NaN      NaN     NaN    NaN   NaN
# 216             NaN       NaN         NaN      NaN     NaN    NaN   NaN
#
#      PumpPrice  Military  Health  ...  Diabetes  BirthRate  DeathRate  \
# ...

# %%
df.head()
# Out:
#           Country  LandArea  Population  Density     GDP  Rural   CO2  \
# 0     Afghanistan    652.86      30.552     46.8   665.0   74.1  35.3
# 1         Albania     27.40       2.897    105.7  4460.0   44.6  12.8
# 2         Algeria   2381.74      39.208     16.5  5361.0   30.5  24.6
# 3  American Samoa      0.20       0.055    275.0     NaN   12.7   NaN
# 4         Andorra      0.47       0.079    168.1     NaN   13.8   9.5
#
#    PumpPrice  Military  Health  ...  Diabetes  BirthRate  DeathRate  \
# 0       1.28      8.65    7.07  ...       8.1       34.1        7.8
# 1       1.81       NaN    9.85  ...       2.6       12.9        6.9
# 2       0.29       NaN    9.43  ...       7.3       24.3        5.9
# 3        NaN       NaN     NaN  ...       NaN        NaN        NaN
# 4       1.67       NaN   23.14  ...       5.4        NaN        NaN
#
#    ElderlyPop  LifeExpectancy  FemaleLabor  Unemployment  EnergyUse  \
# ...

# %%
df.tail()
# Out:
#          Country  LandArea  Population  Density     GDP  Rural   CO2  \
# 212  Yemen, Rep.    527.97      24.407     46.2  1473.0   66.6  31.5
# 213       Zambia    743.39      14.539     19.6  1845.0   60.0  43.0
# 214     Zimbabwe    386.85      14.150     36.6   953.0   67.3  31.6
# 215          NaN       NaN         NaN      NaN     NaN    NaN   NaN
# 216          NaN       NaN         NaN      NaN     NaN    NaN   NaN
#
#      PumpPrice  Military  Health  ...  Diabetes  BirthRate  DeathRate  \
# 212       0.58       NaN    3.93  ...       8.3       31.1        7.2
# 213       1.48       NaN   12.57  ...       5.0       42.8       10.2
# 214       1.52       NaN     NaN  ...       9.3       31.3        9.0
# 215        NaN       NaN     NaN  ...       NaN        NaN        NaN
# 216        NaN       NaN     NaN  ...       NaN        NaN        NaN
#
#      ElderlyPop  LifeExpectancy  FemaleLabor  Unemployment  EnergyUse  \
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['GDP'].tail()
# Out:
# 212    1473.0
# 213    1845.0
# 214     953.0
# 215       NaN
# 216       NaN
# Name: GDP, dtype: float64

# %%
df.set_index("Country")
# Out:
#                 LandArea  Population  Density     GDP  Rural   CO2  PumpPrice  \
# Country
# Afghanistan       652.86      30.552     46.8   665.0   74.1  35.3       1.28
# Albania            27.40       2.897    105.7  4460.0   44.6  12.8       1.81
# Algeria          2381.74      39.208     16.5  5361.0   30.5  24.6       0.29
# American Samoa      0.20       0.055    275.0     NaN   12.7   NaN        NaN
# Andorra             0.47       0.079    168.1     NaN   13.8   9.5       1.67
# ...                  ...         ...      ...     ...    ...   ...        ...
# Yemen, Rep.       527.97      24.407     46.2  1473.0   66.6  31.5       0.58
# Zambia            743.39      14.539     19.6  1845.0   60.0  43.0       1.48
# Zimbabwe          386.85      14.150     36.6   953.0   67.3  31.6       1.52
# NaN                  NaN         NaN      NaN     NaN    NaN   NaN        NaN
# NaN                  NaN         NaN      NaN     NaN    NaN   NaN        NaN
#
# ...

# %%
df["LandArea"].plot()
# Out:
# <AxesSubplot:>

# %%
df["LandArea"].rolling(50).mean().plot()
# Out:
# <AxesSubplot:>
